# %% [markdown]
# # Datta analysis and visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Read the csv file

# %%
df=pd.read_csv('Netflix_Shows.csv',encoding='latin-1')

# %% [markdown]
# # Preview netflix data -- Which features are categorical vs numerical

# %%
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %% [markdown]
# # What is the distribution of numerical feature values across the samples?

# %%
df.describe()
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count         1000.00000   1000.000000         605.000000       1000.000000
# mean            67.36600   2010.335000          84.094215         80.783000
# std             30.78561      8.877927          12.344371          0.973066
# min             10.00000   1940.000000          55.000000         80.000000
# 25%             35.00000   2007.000000          75.000000         80.000000
# 50%             60.00000   2015.000000          88.000000         80.000000
# 75%             90.00000   2016.000000          95.000000         82.000000
# max            124.00000   2017.000000          99.000000         82.000000

# %% [markdown]
# # Which features contain blank, null or empty values?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# title                1000 non-null object
# rating               1000 non-null object
# ratingLevel          941 non-null object
# ratingDescription    1000 non-null int64
# release year         1000 non-null int64
# user rating score    605 non-null float64
# user rating size     1000 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %% [markdown]
# # To find out number of null values in Each column and suming their count

# %%
df.isnull().sum()
# Out:
# title                  0
# rating                 0
# ratingLevel           59
# ratingDescription      0
# release year           0
# user rating score    395
# user rating size       0
# dtype: int64

# %%
df['ratingLevel'].fillna("-",inplace=True)

# %%
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
df['user rating score'].fillna(0,inplace=True)

# %%
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                0.0                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %% [markdown]
# # Check for Missing Values

# %%
df.isnull().sum()
# Out:
# title                0
# rating               0
# ratingLevel          0
# ratingDescription    0
# release year         0
# user rating score    0
# user rating size     0
# dtype: int64

# %% [markdown]
# # Total Number of Ratings

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'R', 'TV-14', 'TV-PG', 'TV-MA', 'TV-Y', 'NR', 'TV-Y7-FV',
#        'UR', 'PG', 'TV-G', 'G', 'TV-Y7'], dtype=object)

# %% [markdown]
# # Total Number of Years

# %%
df['release year'].unique()
# Out:
# array([2004, 2006, 2016, 2008, 2014, 2013, 2017, 2015, 2011, 2009, 2007,
#        2012, 2003, 2001, 2010, 1998, 1999, 1978, 2005, 1993, 2002, 1976,
#        1989, 1996, 1997, 2000, 1994, 1982, 1990, 1940, 1986, 1995, 1991,
#        1992, 1987], dtype=int64)

# %% [markdown]
# # Which years had the most shows?

# %%
df1=df["release year"].value_counts()
df1
# Out:
# 2016    292
# 2015    109
# 2017    100
# 2014     58
# 2013     57
# 2012     45
# 1997     28
# 1998     26
# 2008     22
# 2011     21
# 2010     20
# 2009     20
# 2006     19
# 1999     19
# 2007     18
# 2000     17
# 2003     17
# 2002     15
# 2005     14
# 1993     14
# 2001     11
# 2004      8
# 1990      7
# 1995      6
# 1994      6
# 1982      6
# 1991      5
# 1986      4
# 1976      4
# 1940      3
# 1987      2
# 1989      2
# 1978      2
# 1992      2
# 1996      1
# Name: release year, dtype: int64

# %%
sns.countplot(x=df1,data=df)

# %%
df1.plot(title='Years with the Netlfix Shows',kind="bar")

# %%
#wwe can see that The Top 5 years with most number of shows:2016,2015,2017,2014,2013

# %%
sns.jointplot(data=df, y='user rating score', x='release year')

# %%
d=df['rating'].value_counts()
d
# Out:
# TV-14       234
# PG          170
# TV-MA       148
# G           138
# TV-Y         68
# TV-PG        59
# TV-G         52
# TV-Y7-FV     44
# TV-Y7        38
# R            19
# PG-13        15
# NR           14
# UR            1
# Name: rating, dtype: int64

# %% [markdown]
# # Rating distribution

# %%
sns.distplot(d)

# %% [markdown]
# # How is the Rating distribution?

# %%
d.plot(kind='pie')
plt.show()

# %%
#Most ratings in the dataset are:TV-14,PG,TV-MA,G,TV-Y

# %% [markdown]
# # Average User Rating Score of Different Ratings by Years

# %%
df.groupby(['rating','title']).mean()
# Out:
#                                                              ratingDescription  \
# rating   title
# G        Air Bud: Spikes Back                                               35
#          Air Bud: World Pup                                                 35
#          An American Tail                                                   35
#          An American Tail: Fievel Goes West                                 35
#          An American Tail: The Mystery of the Night Monster                 35
#          An Extremely Goofy Movie                                           35
#          Anastasia                                                          35
#          Atlantis: Milo's Return                                            35
#          Babe: Pig in the City                                              35
#          Back to the Secret Garden                                          35
#          Balto                                                              35
# ...

# %%
df.groupby(['rating']).mean()
# Out:
#           ratingDescription  release year  user rating score  user rating size
# rating
# G                      35.0   1998.855072          31.905797         81.173913
# NR                    124.0   2015.285714          24.857143         81.428571
# PG                     60.0   2007.235294          60.341176         80.558824
# PG-13                  80.0   2006.000000          54.266667         80.533333
# R                     100.0   2011.315789          41.263158         81.052632
# TV-14                  90.0   2014.205128          69.435897         80.393162
# TV-G                   35.0   2011.615385          34.384615         81.076923
# TV-MA                 110.0   2016.006757          57.418919         80.702703
# TV-PG                  70.0   2013.728814          61.118644         80.576271
# TV-Y                   10.0   2010.661765          27.794118         81.264706
# TV-Y7                  41.0   2008.657895          27.236842         81.263158
# ...

# %%
sns.countplot(x='title',hue='rating',data=df)

# %%
sns.countplot(x='rating',data=df)

# %%
rating=df.groupby("rating")['title'].count()
rating
# Out:
# rating
# G           138
# NR           14
# PG          170
# PG-13        15
# R            19
# TV-14       234
# TV-G         52
# TV-MA       148
# TV-PG        59
# TV-Y         68
# TV-Y7        38
# TV-Y7-FV     44
# UR            1
# Name: title, dtype: int64

# %%
sns.countplot(x='user rating score',data=df,palette='coolwarm')

# %%
sns.boxplot(data=df, y='user rating score', x='rating')

# %%
df.groupby((['release year', 'rating'])).mean()
# Out:
#                        ratingDescription  user rating score  user rating size
# release year rating
# 1940         G                      35.0          61.000000         80.000000
# 1976         G                      35.0           0.000000         82.000000
# 1978         PG                     60.0          86.000000         80.000000
# 1982         G                      35.0           0.000000         82.000000
#              PG                     60.0          68.000000         80.000000
# 1986         G                      35.0          67.000000         80.000000
# 1987         PG                     60.0          58.000000         80.000000
# 1989         PG                     60.0          80.000000         80.000000
#              TV-Y7                  41.0           0.000000         82.000000
# 1990         G                      35.0           0.000000         82.000000
#              TV-Y7                  41.0          65.000000         80.000000
# ...

# %%
df.plot.scatter(x='user rating score', y='ratingDescription',cmap='cool')

# %%
df.plot.scatter(x='user rating score', y='release year',cmap='cool')

# %%
df.plot.scatter(x='ratingDescription', y='user rating size',cmap='cool')

# %%
df.plot.scatter(x='ratingDescription', y='release year',cmap='cool')

# %%
d=df[['ratingDescription','release year','user rating size']]

# %% [markdown]
# # Let's define the Independet Variable: X and the Dependent Variable: y

# %%
X = d.iloc[:, :].values

# %%
X
# Out:
# array([[  80, 2004,   80],
#        [ 100, 2006,   82],
#        [  90, 2016,   80],
#        ...,
#        [  35, 2003,   82],
#        [  35, 2013,   82],
#        [  35, 2016,   80]], dtype=int64)

# %%
g=df[['user rating score']]

# %%
y=g.iloc[:,:].values

# %%
y
# Out:
# array([[82.],
#        [ 0.],
#        [98.],
#        [98.],
#        [94.],
#        [95.],
#        [97.],
#        [91.],
#        [98.],
#        [96.],
#        [98.],
#        [95.],
#        [77.],
#        [88.],
#        [ 0.],
#        [ 0.],
#        [96.],
#        [80.],
#        [74.],
#        [97.],
#        [81.],
#        [ 0.],
#        [ 0.],
#        [57.],
#        [95.],
#        [98.],
#        [94.],
#        [98.],
#        [ 0.],
#        [ 0.],
#        [84.],
#        [ 0.],
#        [ 0.],
#        [83.],
#        [ 0.],
#        [ 0.],
#        [82.],
#        [ 0.],
#        [ 0.],
#        [94.],
#        [ 0.],
#        [99.],
#        [89.],
#        [ 0.],
#        [92.],
#        [ 0.],
#        [ 0.],
#        [ 0.],
#        [ 0.],
#        [ 0.],
#        [ 0.],
#        [97.],
#        [98.],
#        [98.],
#        [62.],
#        [96.],
#        [94.],
#        [95.],
#        [97.],
#        [94.],
#        [92.],
#        [91.],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 70% training and 30% test

# %% [markdown]
# # Fitting Simple Linear Regression to the Training set

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train,y_train)
# Out:
# F:\anaconda\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                       warm_start=False)

# %% [markdown]
# # Predicting the Test set results

# %%
y_pred=regressor.predict(X_test)
y_pred
# Out:
# array([86.84482672, 78.49666667,  0.        ,  0.        ,  0.        ,
#         0.        , 56.41166667, 80.3       , 77.8       , 87.9275    ,
#        67.925     ,  0.        ,  0.        , 89.35      ,  0.        ,
#        76.68638889,  0.        , 94.51337425, 80.55      , 86.84482672,
#        98.        , 78.41142857, 82.08357143, 59.7       , 90.30671907,
#        85.95770997,  0.        ,  0.        ,  0.        ,  0.        ,
#         0.        , 87.57885614, 78.49666667, 76.68638889, 73.66333333,
#        82.4672807 , 86.84482672,  0.        ,  0.        ,  0.        ,
#        86.84482672, 81.32857143, 80.99666667,  0.        , 76.68638889,
#         0.        , 85.66095238, 94.51337425, 94.33017241,  0.        ,
#         0.        , 85.95770997, 76.68638889, 82.4672807 , 86.84482672,
#         0.        , 88.96190476, 98.        , 82.425     ,  0.        ,
#        86.84482672, 91.8       , 89.35      , 86.84482672,  0.        ,
# ...

# %%
regressor.score(X, y)
# Out:
# 0.9746017471514957

# %%
from sklearn.metrics import r2_score
a= r2_score(y_test,y_pred)
a
# Out:
# 0.966052005648849
